# %% [markdown]
# # Unidad 1: Laboratorio de Algoritmos Orientado a Inteligencia Artificial
# ## Metodología de Copiloto Crítico - Guía del Estudiante
#
# Esta guía interactiva te enseñará a utilizar modelos de Inteligencia Artificial (ChatGPT, Gemini, Claude, Copilot) como asistentes de desarrollo, pero aplicando una **postura de revisión crítica**.
#
# A lo largo de este laboratorio, verás cómo las IAs suelen devolver código ineficiente, incompleto o con bugs lógicos si no se les provee restricciones claras. Tu misión es probar el código generado en las **Cajas de Verificación**, identificar los fallos de la IA y refinar los prompts para obtener código óptimo.
#
# ---

# %% [markdown]
# ## Minitutorial de Python para Principiantes
# Referencia rápida de sintaxis necesaria para completar el laboratorio.

# %%
# Variables y listas
numeros = [1, 2, 3]
numeros.append(4)

# Condicionales
if len(numeros) > 2:
    print("Lista grande")

# Bucles
for x in numeros:
    print(f"Elemento: {x}")

# Funciones
def duplicar(x: int) -> int:
    return x * 2

# %% [markdown]
# ---
# ## 1. Tema 1: Estructuras de Datos Lineales - El Desafío del Min-Stack
#
# ### El Desafío
# Diseña una clase `MinStack` que soporte operaciones de pila comunes (`push`, `pop`, `top`) y además permita obtener el **elemento mínimo** en tiempo constante $\\mathcal{O}(1)$.
#
# ### Paso A: El Prompt Ingenuo (Naive)
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una clase MinStack en Python con push, pop, top y getMin.\"*
#
# **Instrucciones:**
# 1. Pega el código generado por la IA en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para evaluar si la IA realmente implementó la operación en tiempo constante.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT INGENUO)
# ==========================================
# Pega la clase MinStack devuelta por la IA.

# %%
# --- CAJA DE VERIFICACIÓN 1: PROMPT INGENUO ---
try:
    assert 'MinStack' in globals(), "No se encontró la clase 'MinStack'. Asegúrate de pegar el código de tu IA y ejecutar esa celda primero."
    
    # 1. Prueba de correctitud básica
    s = MinStack()
    s.push(5)
    s.push(3)
    s.push(7)
    assert s.getMin() == 3, "Error básico: El mínimo debería ser 3"
    s.pop()
    assert s.getMin() == 3, "Error: pop de 7 no debería cambiar el mínimo que es 3"
    s.pop()
    assert s.getMin() == 5, "Error: Al sacar el 3, el nuevo mínimo debería ser 5"
    
    # 2. Prueba de rendimiento temporal: ¿Es O(1) o O(N)?
    # Si la IA usó min(self.stack) en getMin(), la complejidad es lineal O(N).
    import time
    large_stack = MinStack()
    # Llenamos la pila con 50,000 elementos
    for i in range(50000, 0, -1):
        large_stack.push(i)
        
    print("Iniciando prueba de rendimiento (O(1) vs O(N))...")
    start_time = time.time()
    for _ in range(1000):
        _ = large_stack.getMin()
    end_time = time.time()
    
    elapsed = end_time - start_time
    print(f"Tiempo de ejecución para 1000 consultas de getMin en pila de 50k elementos: {elapsed:.5f} segundos.")
    
    # Una solución O(1) toma menos de 0.005 segundos para 1000 consultas.
    # Si toma más de 0.08 segundos, es O(N).
    assert elapsed < 0.05, f"¡ERROR DE RENDIMIENTO! getMin() tomó {elapsed:.4f}s. Esto indica una complejidad de O(N). ¿Tu IA ha sido perezosa y usó min()!"
    
    print("¡Excelente! Tu IA ha diseñado un MinStack en O(1).")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ### Paso B: El Prompt Refinado
# Las IAs suelen implementar `getMin()` utilizando `min(self.items)`, lo que obliga a recorrer toda la pila linealmente $\\mathcal{O}(n)$ cada vez que se solicita el mínimo. Para solucionarlo, debemos obligar a la IA a que utilice una **pila auxiliar** para realizar el seguimiento del mínimo histórico en tiempo constante.
#
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una clase MinStack en Python. Las operaciones push, pop, top y getMin deben ejecutarse estrictamente en tiempo constante O(1). Para lograr que getMin sea O(1), utiliza una pila auxiliar que mantenga el registro de los mínimos históricos en cada estado de la pila principal. No uses la función min() de Python.\"*
#
# **Instrucciones:**
# 1. Pega el nuevo código en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para confirmar la correctitud y la eficiencia.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT REFINADO)
# ==========================================
# Pega la clase MinStack optimizada.

# %%
# --- CAJA DE VERIFICACIÓN 2: PROMPT REFINADO ---
try:
    assert 'MinStack' in globals(), "No se encontró la clase 'MinStack'."
    
    # 1. Validar rendimiento
    import time
    large_stack = MinStack()
    for i in range(50000, 0, -1):
        large_stack.push(i)
        
    print("Evaluando rendimiento del MinStack optimizado...")
    start_time = time.time()
    for _ in range(1000):
        _ = large_stack.getMin()
    end_time = time.time()
    
    elapsed = end_time - start_time
    print(f"Tiempo de ejecución con MinStack optimizado: {elapsed:.5f} segundos.")
    
    assert elapsed < 0.05, f"¡Error! Aún toma demasiado tiempo ({elapsed:.4f}s). Asegúrate de que no uses min()."
    print("✅ ¡EXCELENTE! Tu IA ha diseñado una estructura MinStack O(1) correcta y eficiente.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ---
# ## 2. Tema 2: Análisis Asintótico - Optimización de 3Sum
#
# ### El Desafío
# Dado un arreglo de enteros, encuentra todos los tripletes únicos `[nums[i], nums[j], nums[k]]` tales que su suma sea cero (`nums[i] + nums[j] + nums[k] == 0`) y no se repitan combinaciones.
#
# ### Paso A: El Prompt Ingenuo (Naive)
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función tres_sum_cero(nums) en Python que devuelva todos los grupos de 3 números que sumen 0.\"*
#
# **Instrucciones:**
# 1. Pega el código generado por la IA en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para evaluar la complejidad temporal.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT INGENUO)
# ==========================================
# Pega la función tres_sum_cero devuelta por la IA.

# %%
# --- CAJA DE VERIFICACIÓN 3: PROMPT INGENUO ---
try:
    assert 'tres_sum_cero' in globals(), "No se encontró la función 'tres_sum_cero'. Asegúrate de pegar el código de tu IA y ejecutar esa celda primero."
    
    # 1. Prueba de correctitud básica
    res = tres_sum_cero([-1, 0, 1, 2, -1, -4])
    sorted_res = sorted([sorted(x) for x in res])
    assert sorted_res == [[-1, -1, 2], [-1, 0, 1]], f"Error básico en tripletes: {sorted_res}"
    
    # 2. Prueba de rendimiento temporal: ¿Es O(N^3) o O(N^2)?
    # Si la IA usó tres bucles anidados, la complejidad es cúbica O(N^3).
    import time
    import random
    large_arr = [random.randint(-1000, 1000) for _ in range(600)]
    
    print("Iniciando prueba de rendimiento para O(N^2) vs O(N^3)...")
    start_time = time.time()
    _ = tres_sum_cero(large_arr)
    end_time = time.time()
    
    elapsed = end_time - start_time
    print(f"Tiempo de ejecución para N=600: {elapsed:.5f} segundos.")
    
    # Una solución O(N^2) tarda menos de 0.15 segundos para N=600.
    # Si toma más de 0.8 segundos, es indicativo de O(N^3).
    assert elapsed < 0.5, f"¡ERROR DE RENDIMIENTO! El código tardó {elapsed:.4f}s. Esto es indicativo de O(N^3) (tres bucles anidados). ¡Tu IA ha sido perezosa y no optimizó el algoritmo!"
    
    print("¡Excelente! Tu IA ha diseñado el algoritmo en tiempo cuadrático O(N^2).")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ### Paso B: El Prompt Refinado
# La mayoría de las IAs resuelven 3Sum con la fuerza bruta (tres bucles anidados), lo que resulta en una complejidad cúbica $\\mathcal{O}(n^3)$ inaceptable para arreglos grandes. Para optimizarlo, debemos forzar a la IA a **ordenar el arreglo primero** y luego utilizar la técnica de **dos punteros (two pointers)** para encontrar los pares en tiempo cuadrático $\\mathcal{O}(n^2)$.
#
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función en Python llamada tres_sum_cero(nums: list) -> list que devuelva todos los tripletes únicos que sumen cero. El algoritmo debe ser óptimo con una complejidad temporal de O(N^2). Para lograrlo, primero ordena la lista y luego utiliza la técnica de dos punteros (izquierdo y derecho) recorriendo la lista con un bucle principal. Asegúrate de evitar duplicados saltándote elementos repetidos tanto en el bucle principal como en los movimientos de los dos punteros.\"*
#
# **Instrucciones:**
# 1. Pega el nuevo código en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para confirmar la correctitud y la eficiencia.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT REFINADO)
# ==========================================
# Pega la función tres_sum_cero optimizada.

# %%
# --- CAJA DE VERIFICACIÓN 4: PROMPT REFINADO ---
try:
    assert 'tres_sum_cero' in globals(), "No se encontró la función 'tres_sum_cero'."
    
    # 1. Validar rendimiento
    import time
    import random
    large_arr = [random.randint(-1000, 1000) for _ in range(600)]
    
    print("Evaluando rendimiento del algoritmo tres_sum_cero optimizado...")
    start_time = time.time()
    _ = tres_sum_cero(large_arr)
    end_time = time.time()
    
    elapsed = end_time - start_time
    print(f"Tiempo de ejecución con algoritmo optimizado: {elapsed:.5f} segundos.")
    
    assert elapsed < 0.2, f"¡Error! Aún toma demasiado tiempo ({elapsed:.4f}s). Asegúrate de no usar tres bucles anidados."
    print("✅ ¡EXCELENTE! Tu IA ha optimizado el algoritmo a O(N^2) usando ordenamiento y dos punteros.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ---
# ## 3. Tema 3: Recursividad - Escalones con Memoización
#
# ### El Desafío
# Estás subiendo una escalera que tiene $n$ escalones. Cada vez puedes dar un paso de 1 o de 2 escalones. ¿De cuántas formas distintas puedes subir hasta la cima?
#
# ### Paso A: El Prompt Ingenuo (Naive)
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función recursiva subir_escalones(n) en Python que devuelva la cantidad de formas de subir n escalones dando pasos de 1 o 2.\"*
#
# **Instrucciones:**
# 1. Pega el código generado por la IA en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para evaluar si la IA aplicó la optimización de memoización.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT INGENUO)
# ==========================================
# Pega la función subir_escalones devuelta por la IA.

# %%
# --- CAJA DE VERIFICACIÓN 5: PROMPT INGENUO ---
import time

try:
    assert 'subir_escalones' in globals(), "No se encontró la función 'subir_escalones'. Asegúrate de pegar el código de tu IA y ejecutar esa celda primero."
    
    # 1. Prueba de Correctitud básica
    assert subir_escalones(1) == 1, "Error básico: subir_escalones(1) debería ser 1"
    assert subir_escalones(2) == 2, "Error básico: subir_escalones(2) debería ser 2"
    assert subir_escalones(3) == 3, "Error básico: subir_escalones(3) debería ser 3"
    assert subir_escalones(4) == 5, "Error básico: subir_escalones(4) debería ser 5"

    # 2. PRUEBA DE EFICIENCIA RECURSIVA: ¿Es O(2^n) o O(n)?
    # Si n = 38, una función O(2^N) requiere millones de llamadas recursivas redundantes y tomará varios segundos.
    print("Iniciando prueba de eficiencia recursiva con n=38...")
    
    start_time = time.time()
    res = subir_escalones(38)
    end_time = time.time()
    
    elapsed = end_time - start_time
    print(f"Resultado obtenido: {res}")
    print(f"Tiempo de ejecución para n=38: {elapsed:.5f} segundos.")
    
    # Una solución eficiente O(N) tarda menos de 0.01 segundos.
    assert elapsed < 0.1, f"¡ERROR DE RENDIMIENTO! La función tardó {elapsed:.4f}s en n=38. Esto indica una complejidad exponencial O(2^n). Tu IA no implementó memorización y está recalculando caminos."
    
    print("¡Felicidades! Tu IA diseñó una recursión óptima con memoización.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ### Paso B: El Prompt Refinado
# El código de la IA suele fallar para $n \\ge 35$ porque realiza llamadas duplicadas exponenciales $\\mathcal{O}(2^N)$ que bloquean el kernel. Debemos instruir a la IA para que mantenga la lógica recursiva pero aplique **Memoización** (guardar resultados ya calculados en un caché o diccionario) para reducir la complejidad a tiempo lineal $\\mathcal{O}(N)$.
#
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función recursiva en Python llamada subir_escalones(n) que calcule el número de formas de subir n escalones (dando pasos de 1 o 2). El algoritmo DEBE ser recursivo pero estar optimizado a complejidad temporal lineal O(N) utilizando memoización (por ejemplo, usando un diccionario de caché para almacenar resultados previos, o usando el decorador functools.lru_cache en Python). Asegúrate de manejar el caso base de forma correcta y que pueda calcular subir_escalones(40) instantáneamente sin superar el límite de recursión.\"*
#
# **Instrucciones:**
# 1. Pega el nuevo código en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para confirmar la corrección.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT REFINADO)
# ==========================================
# Pega la función subir_escalones optimizada.

# %%
# --- CAJA DE VERIFICACIÓN 6: PROMPT REFINADO ---
try:
    assert 'subir_escalones' in globals(), "No se encontró la función 'subir_escalones'."
    
    # Evaluamos rendimiento con n=40
    import time
    start_time = time.time()
    res = subir_escalones(40)
    end_time = time.time()
    
    elapsed = end_time - start_time
    print(f"Resultado para n=40: {res}")
    print(f"Tiempo de ejecución para n=40: {elapsed:.5f} segundos.")
    
    assert elapsed < 0.05, f"¡Error! Aún toma demasiado tiempo ({elapsed:.4f}s). Asegúrate de haber memorizado."
    print("✅ ¡EXCELENTE! La IA ha implementado recursión eficiente con O(N) de complejidad mediante memoización.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ---
# ## 4. Tema 4: Búsquedas - Búsqueda Binaria de la Primera Ocurrencia
#
# ### El Desafío
# Dado un arreglo ordenado de enteros que contiene duplicados, encuentra el **primer índice (el más a la izquierda)** en el que aparece un número objetivo `target`. Si no existe, retorna -1. El algoritmo debe ejecutarse en tiempo logarítmico $\\mathcal{O}(\\log n)$.
#
# ### Paso A: El Prompt Ingenuo (Naive)
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función buscar_primero(arr, target) en Python que devuelva la posición del elemento usando búsqueda binaria.\"*
#
# **Instrucciones:**
# 1. Pega el código generado por la IA en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para evaluar si la IA consideró los duplicados ordenados.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT INGENUO)
# ==========================================
# Pega la función buscar_primero devuelta por la IA.

# %%
# --- CAJA DE VERIFICACIÓN 7: PROMPT INGENUO ---
try:
    assert 'buscar_primero' in globals(), "No se encontró la función 'buscar_primero'. Asegúrate de pegar el código de tu IA y ejecutar esa celda primero."
    
    # 1. Probar con duplicados
    # La búsqueda binaria estándar puede retornar cualquier posición del número 2 (índice 2, 3 o 4).
    # Queremos estrictamente la primera ocurrencia (índice 1).
    lista_prueba = [1, 2, 2, 2, 3, 4]
    print(f"Probando caso con duplicados {lista_prueba}, buscando 2...")
    res = buscar_primero(lista_prueba, 2)
    print(f"Índice retornado por tu IA: {res}")
    
    assert res == 1, f"¡ERROR DE LÓGICA! Tu IA retornó el índice {res}. Sin embargo, la primera ocurrencia de 2 está en el índice 1. ¿La IA ha fallado en asegurar que sea la primera ocurrencia!"
    print("¡Correctitud básica y duplicados validados con éxito!")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ### Paso B: El Prompt Refinado
# La mayoría de las IAs devuelven una búsqueda binaria estándar. Al encontrar el `target`, retornan inmediatamente `mid`, sin importar si es la primera o la última ocurrencia del número repetido. Para solucionarlo, debemos indicarle que cuando encuentre el `target` en `mid`, no retorne inmediatamente, sino que continúe la búsqueda en la mitad izquierda (`high = mid - 1`) guardando temporalmente la posición actual.
#
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función en Python llamada buscar_primero(arr: list, target: int) -> int que busque un número en una lista ordenada utilizando búsqueda binaria. Si la lista contiene números duplicados, la función debe garantizar que retorna la posición del primer elemento (el que está más a la izquierda). Si no existe, debe retornar -1. El algoritmo debe ser estrictamente O(log N) en tiempo y O(1) en espacio. Cuando encuentres el elemento en la posición 'mid', no lo retornes inmediatamente; registra esa posición en una variable y continúa reduciendo el espacio de búsqueda hacia la izquierda.\"*
#
# **Instrucciones:**
# 1. Pega el nuevo código en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para confirmar la correcta implementación.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT REFINADO)
# ==========================================
# Pega la función buscar_primero optimizada por la IA.

# %%
# --- CAJA DE VERIFICACIÓN 8: PROMPT REFINADO ---
try:
    assert 'buscar_primero' in globals(), "No se encontró la función 'buscar_primero'. Asegúrate de pegar el código de tu IA y ejecutar esa celda primero."
    
    # 1. Validar duplicados complejos
    lista_dups = [1, 1, 1, 2, 2, 2, 2, 2, 3, 3, 4]
    assert buscar_primero(lista_dups, 1) == 0, "Error: El primer 1 está en la posición 0"
    assert buscar_primero(lista_dups, 2) == 3, "Error: El primer 2 está en la posición 3"
    assert buscar_primero(lista_dups, 3) == 8, "Error: El primer 3 está en la posición 8"
    assert buscar_primero(lista_dups, 4) == 10, "Error: El primer 4 está en la posición 10"
    assert buscar_primero(lista_dups, 5) == -1, "Error: 5 no existe, debe retornar -1"
    
    # 2. Validar complejidad temporal O(log N)
    lista_gigante = list(range(1000000))
    import time
    start = time.time()
    idx_gigante = buscar_primero(lista_gigante, 999999)
    end = time.time()
    
    assert idx_gigante == 999999, "Error en búsqueda binaria de lista gigante"
    assert (end - start) < 0.01, "Error: La búsqueda tomó demasiado tiempo, ¿es O(N) en lugar de O(log N)?"
    
    print("✅ ¡EXCELENTE! La IA devolvió el primer índice correcto en tiempo logarítmico O(log N) manejando duplicados.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ---
# ## 5. Tema 5: Conceptos Básicos y Algoritmos Introductorios con IA - Multiplicación Rusa Campesina
#
# ### El Desafío
# Implementa el algoritmo de **Multiplicación Rusa Campesina** para multiplicar dos enteros positivos $a$ y $b$. Este algoritmo se basa en dividir $b$ por 2 (división entera) y duplicar $a$ consecutivamente hasta que $b$ sea 1, sumando los valores de $a$ en los pasos donde $b$ sea impar. **Todas las operaciones de multiplicación, división por 2 y verificación de paridad dentro del bucle deben realizarse mediante operadores de bits (<<, >>, &) para máxima eficiencia.**
#
# ### Paso A: El Prompt Ingenuo (Naive)
# Copia y pega la siguiente instrucción en tu IA preferida:
#
# > *\"Escribe una función en Python para implementar la multiplicación rusa.\"*
#
# **Instrucciones:**
# 1. Pega el código generado por la IA en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para ver si tu IA resolvió el problema de manera óptima.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT INGENUO)
# ==========================================
# Pega la función multiplicacion_rusa devuelta por la IA.

# %%
# --- CAJA DE VERIFICACIÓN 9: PROMPT INGENUO ---
try:
    assert 'multiplicacion_rusa' in globals(), "No se encontró la función 'multiplicacion_rusa'. Asegúrate de pegar el código de tu IA y ejecutar esa celda primero."
    
    # 1. Probar correctitud básica
    assert multiplicacion_rusa(3, 4) == 12, "Error: 3 * 4 debe ser 12"
    assert multiplicacion_rusa(12, 13) == 156, "Error: 12 * 13 debe ser 156"
    assert multiplicacion_rusa(0, 100) == 0, "Error: 0 * 100 debe ser 0"
    
    # 2. Verificar que no use recursión profunda que cause RecursionError para números grandes
    res = multiplicacion_rusa(5, 50000)
    assert res == 250000, "Error con b = 50000"
    
    print("¡Correctitud básica verificada! Procede al paso B si falló o si no usó operadores de bits en el bucle.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ### Paso B: El Prompt Refinado
# Las IAs suelen implementar este algoritmo de forma recursiva (lo que consume memoria en la pila $\\mathcal{O}(\\log B)$ y puede desbordarse) o utilizando operaciones aritméticas comunes (`* 2`, `// 2`, `% 2`). Para optimizarlo a nivel de hardware, debemos exigir a la IA que use **operadores de bits** en un diseño estrictamente iterativo.
#
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función iterativa en Python llamada multiplicacion_rusa(a: int, b: int) -> int que multiplique dos enteros positivos usando el método ruso campesino. El algoritmo debe usar estrictamente operadores de bits de Python (>> 1 para división por 2, << 1 para multiplicar por 2, y & 1 para verificar impares) en lugar de operadores aritméticos tradicionales (/ 2, * 2, % 2) dentro del bucle. Debe tener una complejidad temporal de O(log b) y espacial O(1). Mapea los casos de borde si alguno es cero.\"*
#
# **Instrucciones:**
# 1. Pega el nuevo código en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación final.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT REFINADO)
# ==========================================
# Pega la función multiplicacion_rusa optimizada.

# %%
# --- CAJA DE VERIFICACIÓN 10: PROMPT REFINADO ---
try:
    assert 'multiplicacion_rusa' in globals(), "No se encontró la función 'multiplicacion_rusa'."
    assert multiplicacion_rusa(9, 9) == 81, "Error en 9 * 9"
    assert multiplicacion_rusa(1000, 1000) == 1000000, "Error en 1000 * 1000"
    assert multiplicacion_rusa(0, 10) == 0, "Error con multiplicando cero"
    assert multiplicacion_rusa(10, 0) == 0, "Error con multiplicador cero"
    print("✅ ¡EXCELENTE! Tu IA ha implementado la multiplicación rusa iterativa y eficiente usando bits.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ---
# ## 6. Tema 6: Notación Asintótica Avanzada con IA - Comparación de Crecimiento de Funciones
#
# ### El Desafío
# Determina cuál de las siguientes funciones tiene una tasa de crecimiento asintótico mayor cuando $n \\to \\infty$:
# $$f(n) = n^{\\log_2 n} \\quad \\text{o} \\quad g(n) = (\\log_2 n)^n$$
# Implementa una función `comparar_crecimiento(n: int) -> str` que retorne cuál es mayor para un valor $n$ dado. **Debido a que g(n) crece extremadamente rápido, evaluar las funciones directamente causará un OverflowError para valores medianos o grandes de n (como n >= 300). Debes realizar la comparación en escala logarítmica (aplicando logaritmo natural en ambos lados) para evitar desbordamiento de memoria.**
#
# ### Paso A: El Prompt Ingenuo (Naive)
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función en Python que evalúe y compare qué función crece más rápido entre n^(log2 n) y (log2 n)^n.\"*
#
# **Instrucciones:**
# 1. Pega el código generado por la IA en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para comprobar si la IA manejó el desbordamiento numérico.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT INGENUO)
# ==========================================
# Pega la función comparar_crecimiento devuelta por la IA.

# %%
# --- CAJA DE VERIFICACIÓN 11: PROMPT INGENUO ---
try:
    assert 'comparar_crecimiento' in globals(), "No se encontró la función 'comparar_crecimiento'. Asegúrate de pegar el código de tu IA y ejecutar esa celda primero."
    
    res = comparar_crecimiento(16)
    assert res in ['g(n)', 'g', '(log2 n)^n'], f"Error para n=16: g(n) debe ser mayor pero obtuviste: {res}"
    
    try:
        res_grande = comparar_crecimiento(500)
        assert res_grande in ['g(n)', 'g', '(log2 n)^n'], "Error con n=500"
    except OverflowError:
        raise AssertionError("La función de tu IA falló por desbordamiento numérico (OverflowError). No aplicó la comparación en escala logarítmica.")
        
    print("¡Correctitud básica verificada! Tu IA manejó números grandes de alguna manera.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ### Paso B: El Prompt Refinado
# Las IAs suelen programar las funciones tal como están escritas. Evaluar $(\\log_2 500)^{500}$ excede el límite de representación de punto flotante en Python y arroja un `OverflowError`. Para solucionarlo, debemos pedirle a la IA que simplifique algebraicamente aplicando logaritmo natural $\\ln$ en ambos lados y comparando los valores de $\\ln(f(n))$ y $\\ln(g(n))$ para evitar desbordar la memoria.
#
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una función en Python llamada 'comparar_crecimiento(n: int) -> str' que determine cuál de las siguientes funciones es mayor para un valor n dado: f(n) = n^(log2 n) o g(n) = (log2 n)^n. Debido a que g(n) crece extremadamente rápido, evaluar las funciones directamente causará un OverflowError para valores medianos o grandes de n (como n >= 300). Para solucionar esto, implementa la comparación en escala logarítmica evaluando ln(f(n)) y ln(g(n)) utilizando propiedades logarítmicas simplificadas, y retorna 'f(n)' o 'g(n)' según corresponda.\"*
#
# **Instrucciones:**
# 1. Pega el nuevo código en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para confirmar que no ocurra desbordamiento.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT REFINADO)
# ==========================================
# Pega la función comparar_crecimiento optimizada.

# %%
# --- CAJA DE VERIFICACIÓN 12: PROMPT REFINADO ---
try:
    assert 'comparar_crecimiento' in globals(), "No se encontró la función 'comparar_crecimiento'."
    res = comparar_crecimiento(500)
    assert res in ['g(n)', 'g', '(log2 n)^n'], f"Error con n=500: {res}"
    res2 = comparar_crecimiento(1000)
    assert res2 in ['g(n)', 'g', '(log2 n)^n'], f"Error con n=1000: {res2}"
    print("✅ ¡EXCELENTE! Tu IA ha implementado la comparación en escala logarítmica evitando desbordamientos de memoria.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ---
# ## 7. Tema 7: Análisis de Algoritmos Iterativos con IA - Búsqueda Lineal con Centinela
#
# ### El Desafío
# Implementa el algoritmo de **Búsqueda Lineal con Centinela** (Sentinel Linear Search). El objetivo es reducir las comparaciones del bucle principal colocando temporalmente el valor buscado al final de la lista. Esto permite omitir la condición de control de límites (`i < len(arr)`) en cada iteración del bucle, haciendo que el bucle principal solo evalúe `arr[i] != target`. **Al terminar la búsqueda, el arreglo debe ser restaurado a su estado original.**
#
# ### Paso A: El Prompt Ingenuo (Naive)
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Escribe una búsqueda lineal con centinela en Python.\"*
#
# **Instrucciones:**
# 1. Pega el código generado por la IA en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para comprobar si la IA comprendió la naturaleza de la optimización del centinela.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT INGENUO)
# ==========================================
# Pega la función buscar_centinela devuelta por la IA.

# %%
# --- CAJA DE VERIFICACIÓN 13: PROMPT INGENUO ---
try:
    assert 'buscar_centinela' in globals(), "No se encontró la función 'buscar_centinela'. Asegúrate de pegar el código de tu IA."
    
    arr = [10, 20, 30, 40]
    assert buscar_centinela(arr, 30) == 2, "Error: 30 está en el índice 2"
    assert buscar_centinela(arr, 50) == -1, "Error: 50 no está en la lista"
    
    class TrackedList(list):
        def __init__(self, *args):
            super().__init__(*args)
            self.mutated = False
        def __setitem__(self, index, value):
            self.mutated = True
            super().__setitem__(index, value)
            
    tl = TrackedList([10, 20, 30, 40])
    res = buscar_centinela(tl, 50)
    assert tl.mutated == True, "¡ERROR! La lista no fue modificada durante la búsqueda. Tu IA no implementó una búsqueda con centinela real, sino una búsqueda lineal común."
    assert res == -1, "Error en retorno de centinela"
    print("¡Correctitud básica y mutación de centinela verificadas!")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ### Paso B: El Prompt Refinado
# La mayoría de las IAs implementan una búsqueda lineal estándar pero la renombran, o colocan el centinela al final de la lista pero **aún mantienen** la comparación de límites de índice `i < len(arr)` dentro del bucle `while`. Además, un bug muy común es que la IA muta la lista pero olvida restaurar el último elemento original antes de retornar el resultado. Debemos guiarla críticamente en estos aspectos.
#
# Copia y pega la siguiente instrucción en tu IA:
#
# > *\"Implementa Búsqueda Lineal con Centinela (Sentinel Linear Search) en Python. La función debe llamarse buscar_centinela(arr: list, target: int) -> int. El algoritmo debe poner temporalmente el target al final de la lista para eliminar la comprobación de límites (i < len(arr)) en el bucle principal (el bucle while sólo debe comparar arr[i] != target). Restaura el arreglo al final para que no quede modificado y retorna el índice correcto o -1 si el target no existía originalmente. Maneja arreglos vacíos de forma segura retornando -1 sin mutar.\"*
#
# **Instrucciones:**
# 1. Pega el nuevo código en la celda de abajo.
# 2. Ejecuta la celda de código.
# 3. Ejecuta la celda de verificación de abajo para confirmar la correcta implementación.

# %%
# ==========================================
# PEGA AQUÍ EL CÓDIGO DE LA IA (PROMPT REFINADO)
# ==========================================
# Pega la función buscar_centinela optimizada.

# %%
# --- CAJA DE VERIFICACIÓN 14: PROMPT REFINADO ---
try:
    assert 'buscar_centinela' in globals(), "No se encontró la función 'buscar_centinela'."
    
    class TrackedList(list):
        def __init__(self, *args):
            super().__init__(*args)
            self.mutated = False
        def __setitem__(self, index, value):
            self.mutated = True
            super().__setitem__(index, value)
            
    tl = TrackedList([1, 3, 5, 7])
    assert buscar_centinela(tl, 5) == 2, "Error al buscar un número existente"
    assert tl.mutated == True, "La lista debe mutar para insertar el centinela."
    assert tl == [1, 3, 5, 7], "¡ERROR! La función mutó la lista pero no la restauró a su estado original al terminar. Esto corrompe los datos del usuario."
    assert buscar_centinela([], 5) == -1, "Error con lista vacía"
    print("✅ ¡EXCELENTE! Tu IA ha diseñado una Búsqueda Lineal con Centinela que muta, busca eficientemente y restaura la lista correctamente.")
except AssertionError as e:
    print(f"❌ PRUEBA FALLIDA: {e}")
except Exception as e:
    print(f"💥 ERROR INESPERADO AL EJECUTAR LAS PRUEBAS: {e}")

# %% [markdown]
# ---
# ## 8. Conclusiones y Reflexión
#
# ¡Felicidades por completar la Unidad 1 con Inteligencia Artificial!
#
# Al finalizar este laboratorio, has aprendido:
# 1. **Que la IA no es infalible**: Si confías ciegamente en ella, introducirás código ineficiente (mal Big-O), con bugs lógicos o lento en tus sistemas.
# 2. **El poder de las pruebas de verificación**: Escribir aserciones unitarias te da la seguridad de que tu código funciona según las especificaciones técnicas y límites definidos.
# 3. **La Ingeniería de Prompts basada en restricciones**: En lugar de reescribir el código tú mismo, aprendiste a guiar a la IA usando conceptos formales de la computación (Complejidad Asintótica Big-O, Pilas Auxiliares, Punteros, Memorización, Operadores de Bits, Centinelas).
#
# Esta es tu arma diferenciadora: en el mundo laboral real, no solo sabes programar, sino que sabes **dirigir, evaluar y asegurar la calidad del código generado por IA**.
